# %%
# %load_ext autoreload
# %autoreload 2

# %%
from ..bicycle_bell_sed_models.utils.tools import visualizeArchitecture
from bicycle_bell_sed_models.models.yamnet_base import yamnet_base
from bicycle_bell_sed_models.models.yamnet_lstm_fc import yamnet_lstm_fc
from bicycle_bell_sed_models.models.crnn import crnn
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16580/1285101752.py in <module>
# ----> 1 from ..bicycle_bell_sed_models.utils.tools import visualizeArchitecture
#       2 from bicycle_bell_sed_models.models.yamnet_base import yamnet_base
#       3 from bicycle_bell_sed_models.models.yamnet_lstm_fc import yamnet_lstm_fc
#       4 from bicycle_bell_sed_models.models.crnn import crnn
#
# ImportError: attempted relative import with no known parent package

# %% [markdown]
# YAMNet Extended

# %%
yamnet_extended = yamnet_lstm_fc()
visualizeArchitecture(yamnet_extended)

# %% [markdown]
# YAMNET Base

# %%
yamnet_base = yamnet_base()
visualizeArchitecture(yamnet_base)

# %% [markdown]
# CRNN

# %%
crnn = crnn()
visualizeArchitecture(crnn)
